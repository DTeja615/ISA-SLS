# %%
import gym
import numpy as np
from gym import wrappers

# GLOBAL SETTINGS
RNG_SEED = 8
POPULATION_SIZE = 100  # Population size
GENERATION_LIMIT = 100  # Max number of generations
DISPLAY_WEIGHTS = False  # Help debug weight update
sigma = 0.1  # noise standard deviation
alpha = 0.00025  # learning rate

def record_interval(n):
    global UPLOAD_GENERATION_INTERVAL
    global POPULATION_SIZE
    episode_interval = (POPULATION_SIZE + 1) * UPLOAD_GENERATION_INTERVAL
    return n % episode_interval == 0


def run_episode(environment, weight):
    obs = environment.reset()
    episode_reward = 0
    done = False
    while not done:
        action = np.matmul(weight.T, obs)
        move = np.argmax(action)
        obs, reward, done, info = environment.step(move)
        episode_reward += reward
    return episode_reward


env = gym.make('LunarLander-v2')

env.seed(RNG_SEED)
np.random.seed(RNG_SEED)

input_size = env.observation_space.shape[0]
output_size = env.action_space.n

# Initial weights
W = np.zeros((input_size, output_size))
plotGen = []
plotGenEval = []
plotGenMean = []
for gen in range(GENERATION_LIMIT):
    # Measure performance per generation
    gen_eval = run_episode(env, W)

    # Keep track of Returns
    R = np.zeros(POPULATION_SIZE)
    # Generate noise
    N = np.random.randn(POPULATION_SIZE, input_size, output_size)
    for j in range(POPULATION_SIZE):
        W_ = W + sigma * N[j]
        R[j] = run_episode(env, W_)

    # Update weights
    # Summation of episode_weight * episode_reward
    weighted_weights = np.matmul(N.T, R).T
    new_W = W + alpha / (POPULATION_SIZE * sigma) * weighted_weights
    if DISPLAY_WEIGHTS:
        print(W)
    W = new_W
    gen_mean = np.mean(R)
    print(
        "Generation {}, Return: {}, Population Mean: {}".format(gen+1,
                                                                gen_eval,
                                                                gen_mean))
    plotGen.append(gen+1)
    plotGenEval.append(gen_eval)
    plotGenMean.append(gen_mean)
env.close()
# Out:
# Generation 1, Return: -135.3932708344443, Population Mean: -501.7353187829203
# Generation 2, Return: -148.68799032614848, Population Mean: -149.25866590612196
# Generation 3, Return: -47.73430365955939, Population Mean: -125.5117237397641
# Generation 4, Return: -65.56927625333692, Population Mean: -92.90796366332593
# Generation 5, Return: -58.53809027308516, Population Mean: -76.60463548372697
# Generation 6, Return: -75.50031312487698, Population Mean: -92.61686568977382
# Generation 7, Return: -120.76368462005573, Population Mean: -70.68715466148579
# Generation 8, Return: 15.623131257517244, Population Mean: -72.97295859094788
# Generation 9, Return: -51.42832844864557, Population Mean: -75.18406730965921
# Generation 10, Return: -32.13674003137345, Population Mean: -65.75661002141881
# Generation 11, Return: -40.48698348435617, Population Mean: -40.38232722044389
# Generation 12, Return: 271.3835606336477, Population Mean: -24.33821463855657
# Generation 13, Return: -22.84785042838857, Population Mean: -20.628952104913434
# Generation 14, Return: 245.73315261816555, Population Mean: 28.632018969667953
# Generation 15, Return: 287.30378866241574, Population Mean: 52.52845098011977
# Generation 16, Return: 242.09300648015835, Population Mean: 37.897280662021224
# Generation 17, Return: 212.93663266712005, Population Mean: 42.43886584873906
# Generation 18, Return: 246.68235411875273, Population Mean: 58.36564210582468
# Generation 19, Return: 229.31815343583838, Population Mean: 128.3848298279806
# Generation 20, Return: 187.23577675565636, Population Mean: 146.9844416197557
# Generation 21, Return: 246.1115382291265, Population Mean: 152.63295170553707
# Generation 22, Return: 251.34310943193248, Population Mean: 150.52588551444921
# Generation 23, Return: 250.96179799954925, Population Mean: 157.6355168663903
# Generation 24, Return: 256.8396468281108, Population Mean: 180.70124490926213
# Generation 25, Return: 248.9851471316425, Population Mean: 204.9419210986533
# Generation 26, Return: 242.98052382701528, Population Mean: 222.68568049953004
# Generation 27, Return: 205.93338965342582, Population Mean: 184.31218682785132
# Generation 28, Return: 224.29706142300728, Population Mean: 196.63504913363013
# Generation 29, Return: 298.75916661502794, Population Mean: 187.4911710486936
# Generation 30, Return: 242.4364545169961, Population Mean: 192.4765935918836
# Generation 31, Return: 240.44264169021656, Population Mean: 171.11871863022836
# Generation 32, Return: 244.94840604786472, Population Mean: 200.9408236531261
# Generation 33, Return: 212.47858774513102, Population Mean: 188.47435523934445
# Generation 34, Return: 174.0789865887557, Population Mean: 195.2164119564308
# Generation 35, Return: 216.24055442453306, Population Mean: 210.81064951257576
# Generation 36, Return: 219.54017197705227, Population Mean: 190.78809507243557
# Generation 37, Return: 218.81020992039169, Population Mean: 193.19309118142223
# Generation 38, Return: 219.9914011149836, Population Mean: 183.99856233862968
# Generation 39, Return: 255.4178531778888, Population Mean: 217.65788775990754
# Generation 40, Return: 267.12760471507147, Population Mean: 210.48135788421263
# Generation 41, Return: 207.56813805711118, Population Mean: 178.30573654445848
# Generation 42, Return: 205.7498019038719, Population Mean: 155.99268307209564
# Generation 43, Return: 225.77458802298713, Population Mean: 173.09118923148634
# Generation 44, Return: 271.7031116736046, Population Mean: 203.9380637803448
# Generation 45, Return: 240.91641045644366, Population Mean: 150.200652675851
# Generation 46, Return: 239.70006191880142, Population Mean: 147.1764307221806
# Generation 47, Return: 254.61135086573697, Population Mean: 191.75909720998598
# Generation 48, Return: 220.0009308987061, Population Mean: 183.616827267075
# Generation 49, Return: 282.12012339483135, Population Mean: 194.1825278819555
# Generation 50, Return: 237.28438160059633, Population Mean: 190.82411438435562
# Generation 51, Return: 251.48198411831987, Population Mean: 168.3468936393124
# Generation 52, Return: 288.3007752060259, Population Mean: 204.4271629950652
# Generation 53, Return: 247.38774858550704, Population Mean: 212.42482724913714
# Generation 54, Return: 276.8073768507876, Population Mean: 197.82482997247934
# Generation 55, Return: 240.03829410145005, Population Mean: 211.5636323144896
# Generation 56, Return: 233.66706988891508, Population Mean: 218.29735194944516
# Generation 57, Return: 231.3996054968124, Population Mean: 221.85376049823918
# Generation 58, Return: 271.27592312710726, Population Mean: 214.28393401397273
# Generation 59, Return: 265.63818192570847, Population Mean: 202.74947827708758
# Generation 60, Return: 247.87334212403363, Population Mean: 215.98573266209007
# Generation 61, Return: 210.47356449783263, Population Mean: 142.1777899959463
# Generation 62, Return: 237.9200762793619, Population Mean: 199.3072377896037
# Generation 63, Return: 258.34582370829673, Population Mean: 167.63599856919677
# Generation 64, Return: -0.7986949409997663, Population Mean: 163.40562878103879
# Generation 65, Return: 188.69717030218703, Population Mean: 206.5556593792146
# Generation 66, Return: 208.79046185118005, Population Mean: 206.6831804556644
# Generation 67, Return: 259.26154348162555, Population Mean: 217.18750735801694
# Generation 68, Return: 228.42029999064005, Population Mean: 203.23748557940564
# Generation 69, Return: 265.1070872570627, Population Mean: 197.8418185814422
# Generation 70, Return: 253.40466359169696, Population Mean: 224.32260940774464
# Generation 71, Return: 274.9368454336528, Population Mean: 218.23555368469155
# Generation 72, Return: 225.37181901172102, Population Mean: 206.90834165240446
# Generation 73, Return: 266.4251642434, Population Mean: 221.2734144883576
# Generation 74, Return: 246.0169934172566, Population Mean: 216.05539595098824
# Generation 75, Return: 233.34386372741906, Population Mean: 227.74523362619036
# Generation 76, Return: 210.19302670762124, Population Mean: 207.46012262675802
# Generation 77, Return: 256.71025047602825, Population Mean: 213.3548494386674
# Generation 78, Return: 239.04460939684353, Population Mean: 222.33427881676045
# Generation 79, Return: 222.72618101418502, Population Mean: 219.80141059010504
# Generation 80, Return: 266.1782192874976, Population Mean: 196.14304181410793
# Generation 81, Return: 237.50724370816613, Population Mean: 210.56081319969883
# Generation 82, Return: 240.63260620115963, Population Mean: 213.16474010396323
# Generation 83, Return: 210.37483547225895, Population Mean: 216.09955525202932
# Generation 84, Return: 275.0627860179195, Population Mean: 232.80191349733857
# Generation 85, Return: 227.55497260308204, Population Mean: 225.12662988045957
# Generation 86, Return: 43.62863409743497, Population Mean: 192.9678677994912
# Generation 87, Return: 244.58877451582418, Population Mean: 222.63982140650495
# Generation 88, Return: 239.36744113559993, Population Mean: 212.7090205304775
# Generation 89, Return: 45.985246454110694, Population Mean: 195.95928448739764
# Generation 90, Return: 271.40693800989243, Population Mean: 205.0147856681619
# Generation 91, Return: 239.85352382545526, Population Mean: 226.02125816496326
# Generation 92, Return: 228.60444434228373, Population Mean: 217.39711024751585
# Generation 93, Return: 264.8737122063798, Population Mean: 223.05927950272817
# Generation 94, Return: 206.6196998957941, Population Mean: 208.21011566412525
# Generation 95, Return: 184.92621975518963, Population Mean: 210.31752474349503
# Generation 96, Return: 226.03748318433009, Population Mean: 222.64038025247805
# Generation 97, Return: 238.0679804373204, Population Mean: 228.18304520801428
# Generation 98, Return: 211.22442254490696, Population Mean: 204.73340067174027
# Generation 99, Return: 252.87942855556548, Population Mean: 213.29618775040396
# Generation 100, Return: 242.9860231458591, Population Mean: 220.37937141272118

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.xlabel('Generations')
plt.ylabel('Average Fitness of Generation')
plt.title('Score moving average', fontstyle='italic')
plt.plot(plotGen,plotGenMean)
plt.savefig('ES_1.pdf')  
plt.show()
